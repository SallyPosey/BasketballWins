# %% [markdown]
# # ***MDC Women's Basketball Season 24-25***

# %% [markdown]
# #Upload the Data
# Each CSV as a seperate dataframe

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import linregress
import statsmodels.api as sm

# Here are all the csvs for my Overal Season Stats
url0 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/BallControl.csv"
BallControl = pd.read_csv(url0)

url1 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/OpponentBallControl.csv"
OpponentBallControl = pd.read_csv(url1)

url2 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/Shooting.csv"
Shooting = pd.read_csv(url2)

url3 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/OpponentShooting.csv"
OpponentShooting = pd.read_csv(url3)

url4 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/Rebounding.csv"
Rebounding = pd.read_csv(url4)

url5 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/OpponentRebounding.csv"
OpponentRebounding = pd.read_csv(url5)

url6 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/PF_EFF.csv"
PF_EFF = pd.read_csv(url6)

url7 = "https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/Opponent_PF_EFF.csv"
Opponent_PF_EFF = pd.read_csv(url7)

# %%
# Here is the csv for my PLayer season stats
player = pd.read_csv("https://raw.githubusercontent.com/SallyPosey/SportsAnalytics/refs/heads/main/PlayerStats.csv")

# %% [markdown]
# #Cleaning

# %% [markdown]
# ## 1. Season Scores Dataframe

# %% [markdown]
# ###Clean columns
# -Example: add "OBC_" to titles of columns in OpponentBallControl
#
# -Drop the 3 null games
#
# -preview each to check work
#
# -take columns with #-# format and convert to two new columns "made" and "attempted"

# %% [markdown]
# ####Ball Control (Self)

# %%
#BallControl column
  #Add "BC_" prefix to columns
columns_to_rename = ['to', 'stl', 'blk', 'ast']
rename_dict = {col: f"BC_{col}" for col in columns_to_rename}
BallControl = BallControl.rename(columns=rename_dict)

  #Remove rows with any null values
BallControl.dropna(inplace=True)

BallControl.head()
# Out:
#      Date                               Opponent      Score BC_to BC_stl  \
# 3   1-Nov        South Georgia Technical College   L, 72-58    21      9
# 4   2-Nov           at Tallahassee State College   W, 82-69    31     12
# 5  15-Nov    vs. Northwest Florida State College   L, 80-58    24     15
# 6  16-Nov  vs. Western Wyoming Community College  W, 101-87    19      5
# 7  22-Nov         vs. East Georgia State College   W, 87-80    13     13
#
#   BC_blk BC_ast
# 3      3      9
# 4      1     10
# 5      6     13
# 6      5     19
# 7      4     13

# %% [markdown]
# ####Opponent Ball Control

# %%
#OpponentBallControl column
  #Add "OBC_" prefix to columns
columns_to_rename = ['to', 'stl', 'blk', 'ast']
rename_dict = {col: f"OBC_{col}" for col in columns_to_rename}
OpponentBallControl = OpponentBallControl.rename(columns=rename_dict)

  #Remove rows with any null values
OpponentBallControl.dropna(inplace=True)

OpponentBallControl.head()
# Out:
#      Date                               Opponent      Score OBC_to OBC_stl  \
# 3   1-Nov        South Georgia Technical College   L, 72-58     31       8
# 4   2-Nov           at Tallahassee State College   W, 82-69     26      17
# 5  15-Nov    vs. Northwest Florida State College   L, 80-58     21      12
# 6  16-Nov  vs. Western Wyoming Community College  W, 101-87     15      11
# 7  22-Nov         vs. East Georgia State College   W, 87-80     19      10
#
#   OBC_blk OBC_ast
# 3       0      20
# 4       1      15
# 5       4      23
# 6       2      19
# 7       3      17

# %% [markdown]
# #### Rebounding (Self)

# %%
#Rebounding column
  #Add "R_" prefix to columns
columns_to_rename = ['off', 'def', 'reb', 'mrgn']
rename_dict = {col: f"R_{col}" for col in columns_to_rename}
Rebounding = Rebounding.rename(columns=rename_dict)

  #Remove rows with any null values
Rebounding.dropna(inplace=True)

Rebounding.head()
# Out:
#      Date                               Opponent      Score R_off R_def R_reb  \
# 3   1-Nov        South Georgia Technical College   L, 72-58    13    16    29
# 4   2-Nov           at Tallahassee State College   W, 82-69    19    25    44
# 5  15-Nov    vs. Northwest Florida State College   L, 80-58    15    20    35
# 6  16-Nov  vs. Western Wyoming Community College  W, 101-87    14    29    43
# 7  22-Nov         vs. East Georgia State College   W, 87-80    18    24    42
#
#   R_mrgn
# 3    -15
# 4     15
# 5     -8
# 6     13
# 7    -10

# %% [markdown]
# ####Opponent Rebounding

# %%
#OpponentRebounding column
  #Add "OR_" prefix to columns
columns_to_rename = ['off', 'def', 'reb', 'mrgn']
rename_dict = {col: f"OR_{col}" for col in columns_to_rename}
OpponentRebounding = OpponentRebounding.rename(columns=rename_dict)

  #Remove rows with any null values
OpponentRebounding.dropna(inplace=True)

OpponentRebounding.head()
# Out:
#      Date                               Opponent      Score OR_off OR_def  \
# 3   1-Nov        South Georgia Technical College   L, 72-58     15     29
# 4   2-Nov           at Tallahassee State College   W, 82-69     10     19
# 5  15-Nov    vs. Northwest Florida State College   L, 80-58     17     26
# 6  16-Nov  vs. Western Wyoming Community College  W, 101-87     10     20
# 7  22-Nov         vs. East Georgia State College   W, 87-80     17     35
#
#   OR_reb OR_mrgn
# 3     44     -15
# 4     29      15
# 5     43      -8
# 6     30      13
# 7     52     -10

# %% [markdown]
# ####Shooting

# %%
#Shooting column


# Assuming the first row contains the column headers
Shooting.columns = Shooting.iloc[0]  # Set the first row as headers
Shooting = Shooting[1:]  # Remove the first row from data

#Add "S_" prefix to column
columns_to_rename = ['fg', 'fg_pct', '3pt', '3pt_pct', 'ft', 'ft_pct']  # Select columns to rename (excluding the first column, likely 'Date')
rename_dict = {col: f"S_{col}" for col in columns_to_rename}  # Create rename dictionary
Shooting = Shooting.rename(columns=rename_dict)  # Rename columns

  #Remove rows with any null values
Shooting.dropna(inplace=True)


Shooting.head()  # Preview changes
# Out:
# 0      Date                         Opponent     Score   S_fg S_fg_pct S_3pt  \
# 1  Oct 15 #         at St. Thomas University                -        -     -
# 2  Oct 19 #              at Barry University                -        -     -
# 3  Oct 23 #        Ft. Lauderdale University                -        -     -
# 4     Nov 1  South Georgia Technical College  L, 72-58  21-39     53.8   1-3
# 5     Nov 2     at Tallahassee State College  W, 82-69  35-56     62.5   2-4
#
# 0 S_3pt_pct   S_ft S_ft_pct   pts
# 1         -      -        -     -
# 2         -      -        -     -
# 3         -      -        -     -
# 4      33.3  15-22     68.2  58.0
# 5      50.0  10-14     71.4  82.0

# %%
# Remove rows with null values.  Null values are represented as '-' in this dataset
Shooting = Shooting[Shooting["pts"] != "-"]
# Display the updated dataframe
Shooting
# Out:
# 0     Date                                      Opponent       Score    S_fg  \
# 4    Nov 1               South Georgia Technical College    L, 72-58   21-39
# 5    Nov 2                  at Tallahassee State College    W, 82-69   35-56
# 6   Nov 15           vs. Northwest Florida State College    L, 80-58   25-65
# 7   Nov 16         vs. Western Wyoming Community College   W, 101-87   42-74
# 8   Nov 22                vs. East Georgia State College    W, 87-80   26-67
# 9   Nov 23                                at DME Academy    W, 77-54   30-73
# 10   Dec 2                Hillsborough Community College    W, 85-75   31-72
# 11   Dec 7                           at Santa Fe College    W, 83-77   31-58
# 12   Dec 9                        St. Petersburg College    W, 97-60   40-86
# 13  Dec 14                 Eastern Florida State College    L, 56-49   18-72
# 14  Dec 16         at Florida Southwestern State College    L, 86-70   27-67
# 15  Dec 18                      at Daytona State College   W, 109-81   42-85
# 16  Dec 30                    at Pensacola State College    L, 76-74   25-78
# 17  Dec 31  vs. Mississippi Gulf Coast Community College    W, 89-76   34-61
# 18   Jan 3            vs. Bryant & Stratton College (VA)    L, 77-75   28-69
# 19   Jan 4                   vs. Montgomery College (MD)   W, 132-68  53-106
# 20  Jan 11                      at Daytona State College    W, 89-78   39-77
# 21  Jan 15                        St. Petersburg College    W, 99-46   35-81
# 22  Jan 18                              Santa Fe College    W, 72-55   25-76
# 23  Jan 22              at Eastern Florida State College    L, 82-68   28-65
# 24  Jan 25            Florida Southwestern State College    W, 77-51   32-79
# 25   Feb 1             at Hillsborough Community College  L, 105-100  39-103
# 26   Feb 5                   at Palm Beach State College    W, 87-60   35-79
# 27  Feb 12                         Daytona State College    W, 78-69   31-78
# 28  Feb 15                     at St. Petersburg College    W, 78-66   26-77
# 29  Feb 19                      Palm Beach State College    W, 90-69   38-70
# 30  Feb 22                 Eastern Florida State College    W, 89-88   27-79
# 31  Feb 26         at Florida Southwestern State College    L, 74-60   26-63
# 32   Mar 1                           at Santa Fe College    W, 80-56   33-83
# 33   Mar 3                Hillsborough Community College    W, 87-60   32-87
# 34  Mar 12                           vs. Chipola College    L, 74-70   28-88
#
# 0  S_fg_pct  S_3pt S_3pt_pct   S_ft S_ft_pct    pts
# 4      53.8    1-3      33.3  15-22     68.2   58.0
# 5      62.5    2-4      50.0  10-14     71.4   82.0
# 6      38.5   5-17      29.4    3-7     42.9   58.0
# 7      56.8   9-17      52.9   8-11     72.7  101.0
# 8      38.8   6-22      27.3  29-44     65.9   87.0
# 9      41.1   7-22      31.8  10-13     76.9   77.0
# 10     43.1   5-21      23.8  18-24     75.0   85.0
# 11     53.4   6-17      35.3  15-20     75.0   83.0
# 12     46.5  11-28      39.3   6-13     46.2   97.0
# 13     25.0   2-14      14.3  11-20     55.0   49.0
# 14     40.3   7-30      23.3   9-13     69.2   70.0
# 15     49.4   6-16      37.5  19-28     67.9  109.0
# 16     32.1   8-30      26.7  16-29     55.2   74.0
# 17     55.7  10-16      62.5  11-17     64.7   89.0
# 18     40.6   7-23      30.4  12-13     92.3   75.0
# 19     50.0  12-26      46.2  14-21     66.7  132.0
# 20     50.6   7-18      38.9    4-9     44.4   89.0
# 21     43.2  13-35      37.1  16-19     84.2   99.0
# 22     32.9   3-21      14.3  19-23     82.6   72.0
# 23     43.1   8-24      33.3    4-8     50.0   68.0
# 24     40.5   5-23      21.7   8-11     72.7   77.0
# 25     37.9  10-28      35.7  12-18     66.7  100.0
# 26     44.3   7-27      25.9  10-26     38.5   87.0
# 27     39.7   6-22      27.3  10-17     58.8   78.0
# 28     33.8   5-16      31.3  21-32     65.6   78.0
# 29     54.3   3-15      20.0  11-14     78.6   90.0
# 30     34.2   6-22      27.3  29-39     74.4   89.0
# 31     41.3   2-12      16.7    6-8     75.0   60.0
# 32     39.8   5-21      23.8   9-18     50.0   80.0
# 33     36.8  11-32      34.4  12-17     70.6   87.0
# 34     31.8   7-32      21.9   7-12     58.3   70.0

# %% [markdown]
# **Split** free throws into two columns (attempted and made)

# %%
#Shooting column S_ft

Shooting[['S_ft_m', 'S_ft_a']] = Shooting['S_ft'].str.split('-', expand=True).astype(int)  # Split and convert to int

# %%
#Shooting column S_3pt

Shooting[['S_3pt_m', 'S_3pt_a']] = Shooting['S_3pt'].str.split('-', expand=True).astype(int)  # Split and convert to int

# %%
Shooting.head()
# Out:
# 0    Date                               Opponent      Score   S_fg S_fg_pct  \
# 4   Nov 1        South Georgia Technical College   L, 72-58  21-39     53.8
# 5   Nov 2           at Tallahassee State College   W, 82-69  35-56     62.5
# 6  Nov 15    vs. Northwest Florida State College   L, 80-58  25-65     38.5
# 7  Nov 16  vs. Western Wyoming Community College  W, 101-87  42-74     56.8
# 8  Nov 22         vs. East Georgia State College   W, 87-80  26-67     38.8
#
# 0 S_3pt S_3pt_pct   S_ft S_ft_pct    pts  S_ft_m  S_ft_a  S_3pt_m  S_3pt_a
# 4   1-3      33.3  15-22     68.2   58.0      15      22        1        3
# 5   2-4      50.0  10-14     71.4   82.0      10      14        2        4
# 6  5-17      29.4    3-7     42.9   58.0       3       7        5       17
# 7  9-17      52.9   8-11     72.7  101.0       8      11        9       17
# 8  6-22      27.3  29-44     65.9   87.0      29      44        6       22

# %% [markdown]
# ####Opponent Shooting

# %%
#OpponentShooting column


# Assuming the first row contains the column headers
OpponentShooting.columns = OpponentShooting.iloc[0] # Set the first row as headers
OpponentShooting = OpponentShooting[1:] # Remove the first row from data

#Add "OS_" prefix to columns
columns_to_rename = ['fg', 'fg_pct', '3pt', '3pt_pct', 'pts' ]  # Select columns to rename
rename_dict = {col: f"OS_{col}" for col in columns_to_rename} # Create rename dictionary
OpponentShooting = OpponentShooting.rename(columns=rename_dict) # Rename columns

  #Remove rows with any null values
OpponentShooting.dropna(inplace=True)

# Remove the 'Date' column
OpponentShooting = OpponentShooting.drop(columns=['Date'])

OpponentShooting.head() # Preview changes
# Out:
# 0                         Opponent     Score  OS_fg OS_fg_pct OS_3pt  \
# 1         at St. Thomas University                -         -      -
# 2              at Barry University                -         -      -
# 3        Ft. Lauderdale University                -         -      -
# 4  South Georgia Technical College  L, 72-58  27-48      56.3   7-19
# 5     at Tallahassee State College  W, 82-69  22-65      33.8   6-21
#
# 0 OS_3pt_pct OS_pts
# 1          -      -
# 2          -      -
# 3          -      -
# 4       36.8   72.0
# 5       28.6   69.0

# %%
# Remove rows with null values.  Null values are represented as '-' in this dataset
OpponentShooting = OpponentShooting[OpponentShooting["OS_pts"] != "-"]
# Display the updated dataframe
OpponentShooting
# Out:
# 0                                       Opponent       Score   OS_fg  \
# 4                South Georgia Technical College    L, 72-58   27-48
# 5                   at Tallahassee State College    W, 82-69   22-65
# 6            vs. Northwest Florida State College    L, 80-58   30-63
# 7          vs. Western Wyoming Community College   W, 101-87   35-70
# 8                 vs. East Georgia State College    W, 87-80   32-73
# 9                                 at DME Academy    W, 77-54   22-68
# 10                Hillsborough Community College    W, 85-75   29-78
# 11                           at Santa Fe College    W, 83-77   31-72
# 12                        St. Petersburg College    W, 97-60   24-54
# 13                 Eastern Florida State College    L, 56-49   19-56
# 14         at Florida Southwestern State College    L, 86-70   33-64
# 15                      at Daytona State College   W, 109-81   32-84
# 16                    at Pensacola State College    L, 76-74   24-81
# 17  vs. Mississippi Gulf Coast Community College    W, 89-76   23-64
# 18            vs. Bryant & Stratton College (VA)    L, 77-75   28-66
# 19                   vs. Montgomery College (MD)   W, 132-68   25-64
# 20                      at Daytona State College    W, 89-78   31-64
# 21                        St. Petersburg College    W, 99-46   20-63
# 22                              Santa Fe College    W, 72-55   23-68
# 23              at Eastern Florida State College    L, 82-68   34-70
# 24            Florida Southwestern State College    W, 77-51   19-65
# 25             at Hillsborough Community College  L, 105-100  37-101
# 26                   at Palm Beach State College    W, 87-60   25-68
# 27                         Daytona State College    W, 78-69   25-70
# 28                     at St. Petersburg College    W, 78-66   26-63
# 29                      Palm Beach State College    W, 90-69   29-74
# 30                 Eastern Florida State College    W, 89-88   35-72
# 31         at Florida Southwestern State College    L, 74-60   27-66
# 32                           at Santa Fe College    W, 80-56   18-65
# 33                Hillsborough Community College    W, 87-60   24-80
# 34                           vs. Chipola College    L, 74-70   28-75
#
# 0  OS_fg_pct OS_3pt OS_3pt_pct OS_pts
# 4       56.3   7-19       36.8   72.0
# 5       33.8   6-21       28.6   69.0
# 6       47.6   5-14       35.7   80.0
# 7       50.0   9-17       52.9   87.0
# 8       43.8  10-30       33.3   80.0
# 9       32.4   6-22       27.3   54.0
# 10      37.2   9-33       27.3   75.0
# 11      43.1   4-21       19.0   77.0
# 12      44.4   5-10       50.0   60.0
# 13      33.9   3-12       25.0   56.0
# 14      51.6   6-19       31.6   86.0
# 15      38.1   5-21       23.8   81.0
# 16      29.6   5-36       13.9   76.0
# 17      35.9   8-25       32.0   76.0
# 18      42.4   8-21       38.1   77.0
# 19      39.1   9-30       30.0   68.0
# 20      48.4  10-30       33.3   78.0
# 21      31.7   2-14       14.3   46.0
# 22      33.8   1-13        7.7   55.0
# 23      48.6   6-18       33.3   82.0
# 24      29.2   5-22       22.7   51.0
# 25      36.6  16-56       28.6  105.0
# 26      36.8   5-15       33.3   60.0
# 27      35.7   7-25       28.0   69.0
# 28      41.3   1-10       10.0   66.0
# 29      39.2   6-16       37.5   69.0
# 30      48.6   5-15       33.3   88.0
# 31      40.9  11-24       45.8   74.0
# 32      27.7   5-25       20.0   56.0
# 33      30.0   6-37       16.2   60.0
# 34      37.3   8-25       32.0   74.0

# %%
#Shooting column OS_fg

OpponentShooting[['OS_fg_m', 'OS_fg_a']] = OpponentShooting['OS_fg'].str.split('-', expand=True).astype(int)  # Split and convert to int

# %%
#Shooting column OS_3pt

OpponentShooting[['OS_3pt_m', 'OS_3pt_a']] = OpponentShooting['OS_3pt'].str.split('-', expand=True).astype(int)  # Split and convert to int

# %%
OpponentShooting.head()
# Out:
# 0                               Opponent      Score  OS_fg OS_fg_pct OS_3pt  \
# 4        South Georgia Technical College   L, 72-58  27-48      56.3   7-19
# 5           at Tallahassee State College   W, 82-69  22-65      33.8   6-21
# 6    vs. Northwest Florida State College   L, 80-58  30-63      47.6   5-14
# 7  vs. Western Wyoming Community College  W, 101-87  35-70      50.0   9-17
# 8         vs. East Georgia State College   W, 87-80  32-73      43.8  10-30
#
# 0 OS_3pt_pct OS_pts  OS_fg_m  OS_fg_a  OS_3pt_m  OS_3pt_a
# 4       36.8   72.0       27       48         7        19
# 5       28.6   69.0       22       65         6        21
# 6       35.7   80.0       30       63         5        14
# 7       52.9   87.0       35       70         9        17
# 8       33.3   80.0       32       73        10        30

# %% [markdown]
# ####Performance Efficiency (Self)

# %%
#PF_EFF column
  #Add "P_" prefix to columns
columns_to_rename = ['pf', 'off eff', 'net eff']
rename_dict = {col: f"P_{col}" for col in columns_to_rename}
PF_EFF = PF_EFF.rename(columns=rename_dict)

  # Remove rows with any null values
PF_EFF.dropna(inplace=True)

PF_EFF.head()
# Out:
#      Date                               Opponent      Score P_pf P_off eff  \
# 3   1-Nov        South Georgia Technical College   L, 72-58   17         1
# 4   2-Nov           at Tallahassee State College   W, 82-69   19     1.093
# 5  15-Nov    vs. Northwest Florida State College   L, 80-58   19     0.748
# 6  16-Nov  vs. Western Wyoming Community College  W, 101-87   12     1.195
# 7  22-Nov         vs. East Georgia State College   W, 87-80   18     1.036
#
#   P_net eff
# 3      0.04
# 4     0.375
# 5    -0.284
# 6     0.128
# 7     0.042

# %% [markdown]
# ####Opponent Performance Efficiency

# %%
#Opponent_PF_EFF column
  #Add "P_" prefix to columns
columns_to_rename = ['pf', 'def eff', 'net eff']
rename_dict = {col: f"OP_{col}" for col in columns_to_rename}
Opponent_PF_EFF = Opponent_PF_EFF.rename(columns=rename_dict)

  # Remove rows with any null values
Opponent_PF_EFF.dropna(inplace=True)

Opponent_PF_EFF.head()
# Out:
#      Date                               Opponent      Score OP_pf OP_def eff  \
# 3   1-Nov        South Georgia Technical College   L, 72-58    24       0.96
# 4   2-Nov           at Tallahassee State College   W, 82-69     0      0.719
# 5  15-Nov    vs. Northwest Florida State College   L, 80-58    10      1.032
# 6  16-Nov  vs. Western Wyoming Community College  W, 101-87    16      1.067
# 7  22-Nov         vs. East Georgia State College   W, 87-80    34      0.994
#
#   OP_net eff
# 3       0.04
# 4      0.375
# 5     -0.284
# 6      0.128
# 7      0.042

# %% [markdown]
# ###Concatenate all the columns, without duplicate columns

# %%
dataframes_to_modify = [OpponentBallControl, Shooting, OpponentShooting, Rebounding, OpponentRebounding, PF_EFF, Opponent_PF_EFF]

for df in dataframes_to_modify:
    if 'Opponent' in df.columns:
        df.drop(columns=['Opponent'], inplace=True)
    if 'Date' in df.columns:
        df.drop(columns=['Date'], inplace=True)

# %%
print(len(BallControl))
# Out:
# 31

# %%
import pandas as pd
from functools import reduce

# List of your DataFrames
dfs = [BallControl, OpponentBallControl, Shooting, OpponentShooting,
       Rebounding, OpponentRebounding, PF_EFF, Opponent_PF_EFF]

# Merge all on the 'Score' column using outer join
merged_df = reduce(lambda left, right: pd.merge(left, right, on="Score", how="outer"), dfs)

# Drop any duplicate rows (if exact duplicates exist)
merged_df = merged_df.drop_duplicates()

# %%
# prompt: how many rows in merged_df

print(len(merged_df))
# Out:
# 285

# %%
#drop exact duplicate rows if any
merged_df = merged_df.drop_duplicates()
print(len(merged_df))
# Out:
# 285

# %%
# prompt: drop any rows that share identical information for the Date column

# Assuming 'Date' is a column in your merged_df
merged_df = merged_df.drop_duplicates(subset=['Date'])
print(len(merged_df))
# Out:
# 31

# %% [markdown]
# ### Modifying the Date column
# *   Adding the year
# *   Changing to datetime type

# %%
import pandas as pd

# Assuming your DataFrame is named merged_df

def add_year(date_str):
    """Adds the appropriate year (2024 or 2025) to the date string."""
    if "Nov" in date_str or "Dec" in date_str:
        return date_str + "-2024"
    else:
        return date_str + "-2025"

# Apply the function to the 'Date' column
merged_df['Date'] = merged_df['Date'].apply(add_year)

# Convert the 'Date' column to datetime objects
merged_df['Date'] = pd.to_datetime(merged_df['Date'], format='%d-%b-%Y')


merged_df.head(10)
# Out:
#         Date                               Opponent       Score BC_to BC_stl  \
# 0 2025-02-01      at Hillsborough Community College  L, 105-100    26     11
# 1 2024-12-14          Eastern Florida State College    L, 56-49    17     10
# 2 2024-11-01        South Georgia Technical College    L, 72-58    21      9
# 3 2025-02-26  at Florida Southwestern State College    L, 74-60    12      8
# 4 2025-03-12                    vs. Chipola College    L, 74-70    12     12
# 5 2024-12-30             at Pensacola State College    L, 76-74    22     12
# 6 2025-01-03     vs. Bryant & Stratton College (VA)    L, 77-75    14     12
# 7 2024-11-15    vs. Northwest Florida State College    L, 80-58    24     15
# 8 2025-01-22       at Eastern Florida State College    L, 82-68    22      7
# 9 2024-12-16  at Florida Southwestern State College    L, 86-70    15      7
#
#   BC_blk BC_ast OBC_to OBC_stl OBC_blk  ... OR_off OR_def OR_reb OR_mrgn P_pf  \
# 0      5     20     21      15       2  ...     22     28     50      16   16
# 1      6     11     21       8       2  ...      8     36     44       7   19
# 2      3      9     31       8       0  ...     15     29     44     -15   17
# 3      2      7     14      10       1  ...     18     27     45     -11   14
# 4      6     15     18       7       3  ...     21     38     59      -2   18
# 5      8     12     12       6       0  ...      7     24     31      26   22
# 6      2     13     12      15       0  ...     19     20     39     -10   19
# 7      6     13     21      12       4  ...     17     26     43      -8   19
# 8      0     10     17      13       1  ...     13     30     43      -5   13
# 9      4     11     21      11       3  ...     18     30     48     -20   21
#
#   P_off eff P_net eff OP_pf  OP_def eff  OP_net eff
# 0     0.901    -0.067    16       0.968      -0.067
# 1     0.645    -0.078    20       0.723      -0.078
# 2         1      0.04    24        0.96        0.04
# 3      0.87    -0.203    13       1.072      -0.203
# 4     0.875    -0.027    11       0.902      -0.027
# 5     0.775      0.03    26       0.745        0.03
# 6     0.932    -0.209    16       1.141      -0.209
# 7     0.748    -0.284    10       1.032      -0.284
# 8      0.84    -0.167    13       1.006      -0.167
# 9     0.915    -0.195    13        1.11      -0.195
#
# [10 rows x 45 columns]

# %% [markdown]
# ###Creating New Columns
# *   Extract PontsGiven and PointsScored from the Score column and make those two new columns
# *   Create a Binary "Wins" column based on Score

# %%
#-------------------------------------------------------------------------------------------------------------------------------------------
#Creating the 'Win' Column and modifying the Score column
merged_df['Win'] = merged_df['Score'].str[0]
merged_df['Score'] = merged_df['Score'].str[2:]

#mapping on win column
merged_df['Win'] = merged_df['Win'].map({'L': 0, 'W': 1})
#----------------------------------------------------------------------------------------------------------------------------------------------------
# Extract PointsScored and PointsGiven from 'Score' column
merged_df[['PointsScored', 'PointsGiven']] = merged_df['Score'].str.split('-', expand=True).astype(int)
#----------------------------------------------------------------------------------------------------------------------------------------------------
# Extract PointsScored and PointsGiven from 'Score' column
merged_df[['PointsScored', 'PointsGiven']] = merged_df['Score'].str.split('-', expand=True).astype(int)
#------------------------------------------------------------------------------------------------------------------------------------------------

#----------------------------------------------------------------------------------------------------------


merged_df.head(20)
# Out:
#          Date                               Opponent     Score BC_to BC_stl  \
# 0  2025-02-01      at Hillsborough Community College   105-100    26     11
# 1  2024-12-14          Eastern Florida State College     56-49    17     10
# 2  2024-11-01        South Georgia Technical College     72-58    21      9
# 3  2025-02-26  at Florida Southwestern State College     74-60    12      8
# 4  2025-03-12                    vs. Chipola College     74-70    12     12
# 5  2024-12-30             at Pensacola State College     76-74    22     12
# 6  2025-01-03     vs. Bryant & Stratton College (VA)     77-75    14     12
# 7  2024-11-15    vs. Northwest Florida State College     80-58    24     15
# 8  2025-01-22       at Eastern Florida State College     82-68    22      7
# 9  2024-12-16  at Florida Southwestern State College     86-70    15      7
# 10 2024-11-16  vs. Western Wyoming Community College    101-87    19      5
# 11 2024-12-18               at Daytona State College    109-81    16     13
# 12 2025-01-04            vs. Montgomery College (MD)    132-68    15     26
# 13 2025-01-18                       Santa Fe College     72-55    17     13
# 14 2025-01-25     Florida Southwestern State College     77-51    12     15
# 15 2024-11-23                         at DME Academy     77-54    11      3
# 16 2025-02-15              at St. Petersburg College     78-66    16      7
# 17 2025-02-12                  Daytona State College     78-69    13     12
# 18 2025-03-01                    at Santa Fe College     80-56    18     20
# 19 2024-11-02           at Tallahassee State College     82-69    31     12
#
#    BC_blk BC_ast OBC_to OBC_stl OBC_blk  ... OR_mrgn P_pf P_off eff P_net eff  \
# 0       5     20     21      15       2  ...      16   16     0.901    -0.067
# 1       6     11     21       8       2  ...       7   19     0.645    -0.078
# 2       3      9     31       8       0  ...     -15   17         1      0.04
# 3       2      7     14      10       1  ...     -11   14      0.87    -0.203
# 4       6     15     18       7       3  ...      -2   18     0.875    -0.027
# 5       8     12     12       6       0  ...      26   22     0.775      0.03
# 6       2     13     12      15       0  ...     -10   19     0.932    -0.209
# 7       6     13     21      12       4  ...      -8   19     0.748    -0.284
# 8       0     10     17      13       1  ...      -5   13      0.84    -0.167
# 9       4     11     21      11       3  ...     -20   21     0.915    -0.195
# 10      5     19     15      11       2  ...      13   12     1.195     0.128
# 11      2     18     21      11       3  ...       8   16     1.147     0.286
# 12      1     34     38      13       2  ...      32   17     1.228      0.52
# 13      3     17     19       6       3  ...      10    6     0.842     0.171
# 14      1     19     22       5       6  ...       2   12     0.945     0.299
# 15      1     13     17       4       0  ...       5   12     1.077     0.327
# 16      3     14     10       6       3  ...      18   17      0.83    -0.062
# 17      1     13     21       4       3  ...       4   16     0.969     0.138
# 18     10     15     31      12      11  ...     -18   18     0.879     0.204
# 19      1     10     26      17       1  ...      15   19     1.093     0.375
#
#    OP_pf OP_def eff OP_net eff Win  PointsScored  PointsGiven
# 0     16      0.968     -0.067   0           105          100
# 1     20      0.723     -0.078   0            56           49
# 2     24       0.96       0.04   0            72           58
# 3     13      1.072     -0.203   0            74           60
# 4     11      0.902     -0.027   0            74           70
# 5     26      0.745       0.03   0            76           74
# 6     16      1.141     -0.209   0            77           75
# 7     10      1.032     -0.284   0            80           58
# 8     13      1.006     -0.167   0            82           68
# 9     13       1.11     -0.195   0            86           70
# 10    16      1.067      0.128   1           101           87
# 11    22      0.862      0.286   1           109           81
# 12    18      0.708       0.52   1           132           68
# 13    19      0.671      0.171   1            72           55
# 14    12      0.646      0.299   1            77           51
# 15    16       0.75      0.327   1            77           54
# 16    17      0.892     -0.062   1            78           66
# 17    18      0.831      0.138   1            78           69
# 18    17      0.675      0.204   1            80           56
# 19     0      0.719      0.375   1            82           69
#
# [20 rows x 48 columns]

# %% [markdown]
# ###Check datatypes

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 284
# Data columns (total 48 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          31 non-null     datetime64[ns]
#  1   Opponent      31 non-null     object
#  2   Score         31 non-null     object
#  3   BC_to         31 non-null     object
#  4   BC_stl        31 non-null     object
#  5   BC_blk        31 non-null     object
#  6   BC_ast        31 non-null     object
#  7   OBC_to        31 non-null     object
#  8   OBC_stl       31 non-null     object
#  9   OBC_blk       31 non-null     object
#  10  OBC_ast       31 non-null     object
#  11  S_fg          31 non-null     object
#  12  S_fg_pct      31 non-null     object
#  13  S_3pt         31 non-null     object
#  14  S_3pt_pct     31 non-null     object
#  15  S_ft          31 non-null     object
#  16  S_ft_pct      31 non-null     object
#  17  pts           31 non-null     object
#  18  S_ft_m        31 non-null     int64
#  19  S_ft_a        31 non-null     int64
#  20  S_3pt_m       31 non-null     int64
#  21  S_3pt_a       31 non-null     int64
#  22  OS_fg         31 non-null     object
#  23  OS_fg_pct     31 non-null     object
#  24  OS_3pt        31 non-null     object
#  25  OS_3pt_pct    31 non-null     object
#  26  OS_pts        31 non-null     object
#  27  OS_fg_m       31 non-null     int64
#  28  OS_fg_a       31 non-null     int64
#  29  OS_3pt_m      31 non-null     int64
#  30  OS_3pt_a      31 non-null     int64
#  31  R_off         31 non-null     object
#  32  R_def         31 non-null     object
#  33  R_reb         31 non-null     object
#  34  R_mrgn        31 non-null     object
#  35  OR_off        31 non-null     object
#  36  OR_def        31 non-null     object
#  37  OR_reb        31 non-null     object
#  38  OR_mrgn       31 non-null     object
#  39  P_pf          31 non-null     object
#  40  P_off eff     31 non-null     object
#  41  P_net eff     31 non-null     object
#  42  OP_pf         31 non-null     object
#  43  OP_def eff    31 non-null     object
#  44  OP_net eff    31 non-null     object
#  45  Win           31 non-null     int64
#  46  PointsScored  31 non-null     int64
#  47  PointsGiven   31 non-null     int64
# dtypes: datetime64[ns](1), int64(11), object(36)
# memory usage: 11.9+ KB

# %% [markdown]
# ###Toubleshooting - Datatypes got messed up
# *   Changing numerical columns dataypes to INT or FLOAT
# *   First I will need to look at what columns are causing me problems with converting

# %%
# Display unique values for problematic columns
problematic_columns = ['S_fg', 'OS_fg', 'OS_fg_pct', 'OS_3pt_pct']
for column in problematic_columns:
    unique_values = merged_df[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print("-" * 20)  # Separator for better readability
# Out:
# Unique values in column 'S_fg':
# ['39-103' '18-72' '21-39' '26-63' '28-88' '25-78' '28-69' '25-65' '28-65'
#  '27-67' '42-74' '42-85' '53-106' '25-76' '32-79' '30-73' '26-77' '31-78'
#  '33-83' '35-56' '31-58' '31-72' '35-79' '26-67' '34-61' '39-77' '27-79'
#  '38-70' '40-86' '35-81']
# --------------------
# Unique values in column 'OS_fg':
# ['37-101' '19-56' '27-48' '27-66' '28-75' '24-81' '28-66' '30-63' '34-70'
#  '33-64' '35-70' '32-84' '25-64' '23-68' '19-65' '22-68' '26-63' '25-70'
#  '18-65' '22-65' '31-72' '29-78' '25-68' '32-73' '23-64' '31-64' '35-72'
#  '29-74' '24-54' '20-63']
# --------------------
# Unique values in column 'OS_fg_pct':
# ['36.6' '33.9' '56.3' '40.9' '37.3' '29.6' '42.4' '47.6' '48.6' '51.6'
#  '50.0' '38.1' '39.1' '33.8' '29.2' '32.4' '41.3' '35.7' '27.7' '43.1'
#  '37.2' '36.8' '43.8' '35.9' '48.4' '39.2' '44.4' '31.7']
# --------------------
# Unique values in column 'OS_3pt_pct':
# ['28.6' '25.0' '36.8' '45.8' '32.0' '13.9' '38.1' '35.7' '33.3' '31.6'
#  '52.9' '23.8' '30.0' '7.7' '22.7' '27.3' '10.0' '28.0' '20.0' '19.0'
#  '37.5' '50.0' '14.3']
# --------------------

# %% [markdown]
# ####The columns OS_fg_pct and OS_3pt_pct are decimal numbers, yet resisting conversion to FLOAT
# *   This is possibly due to spaces, let me handle that

# %%
for column in ['OS_fg_pct', 'OS_3pt_pct']:
    # Replace any non-numeric characters (except for '.') with empty string
    merged_df[column] = merged_df[column].str.replace('[^0-9.]', '', regex=True)
    # Convert to float
    merged_df[column] = pd.to_numeric(merged_df[column], errors='coerce').astype(float)

 # Display unique values for OS_fg_pct and OS_3pt_pct columns
problematic_columns = ['OS_fg_pct', 'OS_3pt_pct']
for column in problematic_columns:
    unique_values = merged_df[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print("-" * 20)  # Separator for better readability
# Out:
# Unique values in column 'OS_fg_pct':
# [36.6 33.9 56.3 40.9 37.3 29.6 42.4 47.6 48.6 51.6 50.  38.1 39.1 33.8
#  29.2 32.4 41.3 35.7 27.7 43.1 37.2 36.8 43.8 35.9 48.4 39.2 44.4 31.7]
# --------------------
# Unique values in column 'OS_3pt_pct':
# [28.6 25.  36.8 45.8 32.  13.9 38.1 35.7 33.3 31.6 52.9 23.8 30.   7.7
#  22.7 27.3 10.  28.  20.  19.  37.5 50.  14.3]
# --------------------

# %% [markdown]
# ####Let me try again to convert the remaining singular numerica columns to INT or FLOAT

# %%
for col in merged_df.columns:
    if col not in ['PointsGiven', 'PointsScored', 'Win', 'OS_3pt_pct', 'OS_fg_pct', 'Date', 'Opponent', 'Score', 'S_fg', 'OS_fg', 'S_3pt', 'S_ft', 'OS_3pt']:
        try:
            # Attempt to convert to int first
            merged_df[col] = merged_df[col].astype(int)
        except ValueError:
            # If int conversion fails, try float
            try:
                merged_df[col] = merged_df[col].astype(float)
            except ValueError:
                # If both fail, it could be a column with mixed types or other issues
                # Handle it appropriately (e.g., investigate further, drop the column, etc.)
                print(f"Warning: Could not convert column '{col}' to int or float.")

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 284
# Data columns (total 48 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          31 non-null     datetime64[ns]
#  1   Opponent      31 non-null     object
#  2   Score         31 non-null     object
#  3   BC_to         31 non-null     int64
#  4   BC_stl        31 non-null     int64
#  5   BC_blk        31 non-null     int64
#  6   BC_ast        31 non-null     int64
#  7   OBC_to        31 non-null     int64
#  8   OBC_stl       31 non-null     int64
#  9   OBC_blk       31 non-null     int64
#  10  OBC_ast       31 non-null     int64
#  11  S_fg          31 non-null     object
#  12  S_fg_pct      31 non-null     float64
#  13  S_3pt         31 non-null     object
#  14  S_3pt_pct     31 non-null     float64
#  15  S_ft          31 non-null     object
#  16  S_ft_pct      31 non-null     float64
#  17  pts           31 non-null     float64
#  18  S_ft_m        31 non-null     int64
#  19  S_ft_a        31 non-null     int64
#  20  S_3pt_m       31 non-null     int64
#  21  S_3pt_a       31 non-null     int64
#  22  OS_fg         31 non-null     object
#  23  OS_fg_pct     31 non-null     float64
#  24  OS_3pt        31 non-null     object
#  25  OS_3pt_pct    31 non-null     float64
#  26  OS_pts        31 non-null     float64
#  27  OS_fg_m       31 non-null     int64
#  28  OS_fg_a       31 non-null     int64
#  29  OS_3pt_m      31 non-null     int64
#  30  OS_3pt_a      31 non-null     int64
#  31  R_off         31 non-null     int64
#  32  R_def         31 non-null     int64
#  33  R_reb         31 non-null     int64
#  34  R_mrgn        31 non-null     int64
#  35  OR_off        31 non-null     int64
#  36  OR_def        31 non-null     int64
#  37  OR_reb        31 non-null     int64
#  38  OR_mrgn       31 non-null     int64
#  39  P_pf          31 non-null     int64
#  40  P_off eff     31 non-null     float64
#  41  P_net eff     31 non-null     float64
#  42  OP_pf         31 non-null     int64
#  43  OP_def eff    31 non-null     float64
#  44  OP_net eff    31 non-null     float64
#  45  Win           31 non-null     int64
#  46  PointsScored  31 non-null     int64
#  47  PointsGiven   31 non-null     int64
# dtypes: datetime64[ns](1), float64(11), int64(29), object(7)
# memory usage: 11.9+ KB

# %% [markdown]
# ###Save new dataframe as a CSV and save to GitHub

# %%
# Save DataFrame to CSV
csv_file_path = "merged_data.csv"  # Choose a file name
merged_df.to_csv(csv_file_path, index=False)  # Save to CSV, index=False to exclude index
print(f"DataFrame saved to: {csv_file_path}")
# Out:
# DataFrame saved to: merged_data.csv

# %% [markdown]
# ## 2. Players Scores Dataframe

# %%
player.head()
# Out:
#    No                Player  T_GP  T_GS  T_MIN  T_AVG  T_FG  T_FGA  T_PCT  \
# 0  15  Shameir Quimby......    31    30    795   25.6   214    496   48.6
# 1  15  Conference Only.....    18    18    553   30.7   126    297   42.4
# 2  23  Clearia Peterson....    31    31    723   23.3   231    477   48.4
# 3  23  Conference Only.....    18    18    517   28.7   147    302   48.7
# 4  21  Kiara Harris........    31    31    774   25.0   155    389   39.8
#
#    3F3  ...  A/G  TO  TO/G  A/TO BLK  BLK/G  STL  STL/G  PTS  AVG.1
# 0    2  ...  4.4  72   2.3   1.9   8    0.3   81    2.6  597   19.3
# 1    1  ...  4.2  42   2.3   1.8   6    0.3   43    2.4  325   18.1
# 2    9  ...  1.5  84   2.7   0.6  24    0.8   47    1.5  560   18.1
# 3    7  ...  1.3  47   2.6   0.5  12    0.7   33    1.8  353   19.6
# 4   98  ...  3.9  97   3.1   1.2   6    0.2   91    2.9  465   15.0
#
# [5 rows x 32 columns]

# %% [markdown]
# #Exploratory Data Analysis
#
# *   Perform an EDA to understand the distribution of features and visualize relationships between features and the target variable.
#
# *   Visualize the distribution of each feature using histograms or boxplots.
#
# *   Create a correlation matrix to identify multicollinearity between features.
#
# *   Create Logistic Regression Model to predict Wins
#
# *   Evaluate Model and Explore Insights

# %% [markdown]
# ## Glossary

# %% [markdown]
# ###Ball Control (BC) & Opponent Ball Control (OBC)
# *   BC_to: Turnovers committed by the team (Ball Control Turnovers)
#
# *   BC_stl: Steals made by the team
#
# *   BC_blk: Blocks made by the team
#
# *   BC_ast: Assists made by the team
#
# *   OBC_to: Turnovers committed by the opponent
#
# *   OBC_stl: Steals made by the opponent
#
# *   OBC_blk: Blocks made by the opponent
#
# *   OBC_ast: Assists made by the opponent
#
# ###Shooting Stats (Self = S_, Opponent = OS_)
# *   S_fg: Field goals made by the team
#
# *   S_fg_pct: Team field goal percentage
#
# *   S_3pt: Three-point field goals made
#
# *   S_3pt_pct: Three-point percentage
#
# *   S_ft: Free throws made
#
# *   S_ft_pct: Free throw percentage
#
# *   pts: Total points scored by the team
#
# *   OS_fg: Field goals made by opponent
#
# *   OS_fg_pct: Opponent field goal percentage
#
# *   OS_3pt: Opponent three-pointers made
#
# *   OS_3pt_pct: Opponent three-point percentage
#
# *   OS_pts: Opponent total points
#
# ###Rebounds (R_ = Team, OR_ = Opponent)
# *   R_off: Team offensive rebounds
#
# *   R_def: Team defensive rebounds
#
# *   R_reb: Total team rebounds
#
# *   R_mrgn: Rebounding margin (team rebounds - opponent rebounds)
#
# *   OR_off: Opponent offensive rebounds
#
# *   OR_def: Opponent defensive rebounds
#
# *   OR_reb: Opponent total rebounds
#
# *   OR_mrgn: Opponent rebounding margin
#
# ###Fouls and Efficiency
# *   P_pf: Personal fouls committed by the team
#
# *   P_off eff: Team offensive efficiency (points per possession)
#
# *   P_net eff: Team net efficiency (offensive eff - defensive eff)
#
# *   OP_pf: Personal fouls committed by opponent
#
# *   OP_def eff: Opponent defensive efficiency
#
# *   OP_net eff: Opponent net efficiency

# %% [markdown]
# ## 1. Distribution of Features / Split the Data

# %% [markdown]
# ###Features for Model A:
#
# *   field goal percentage - (S_fg_pct)
# *   turn overs ------------------------(BC_to)
# *   three pointers made ----(S_3pt_m)
# *   steals ------------------------------(BC_stl)
# *   total rebounds ----------------- (R_reb)
# *   free throw percentage - (S_ft_pct)
#
# ###Features for Model B:
# *   field goal percentage - (S_fg_pct)
# *   turn overs ------------------------(BC_to)
# *   three pointer percentage ----(S_3pt_pct)
# *   steals ------------------------------(BC_stl)
# *   total rebounds ----------------- (R_reb)
# *   free throw percentage - (S_ft_pct)

# %%
#Split the data Model A
X = merged_df[['S_fg_pct', 'BC_to', 'S_3pt_m', 'BC_stl', 'R_reb', 'S_ft_pct']]
y = merged_df['Win']

# %%
#Split the data Model B
X2 = merged_df[['S_fg_pct', 'BC_to', 'S_3pt_pct', 'BC_stl', 'R_reb', 'S_ft_pct']]
y = merged_df['Win']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns  # Import seaborn for KDE

# Calculate total number of plots (excluding the constant)
num_plots = len(X.columns[1:])  # Assuming the first column is the constant

# Calculate number of rows and columns for grid
num_cols = 2  # 2-column grid
num_rows = (num_plots + num_cols - 1) // num_cols  # Calculate rows, ensuring enough space

# Create subplots with grid layout
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 15))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Plot histograms and KDE for features in X, excluding the constant
for i, col in enumerate(X.columns[1:]):  # Start from index 1 to skip the constant
    X[col].hist(ax=axes[i], color='steelblue')  # Changed to 'steelblue'
    axes[i].set_title(col)
    if col == 'S_3pt_m':
        axes[i].patch.set_facecolor('yellow')  # Keep yellow highlighting


# Plot S_3pt_pct in the appropriate subplot
X2['S_3pt_pct'].hist(ax=axes[len(X.columns[1:]) - 1 ], color='steelblue')  # Changed to 'steelblue'
axes[len(X.columns[1:]) - 1].set_title('S_3pt_pct')
axes[len(X.columns[1:])-1].patch.set_facecolor('yellow')  # Keep yellow highlighting


# Hide any unused subplots to avoid repetition
for i in range(num_plots, len(axes)):
    axes[i].set_visible(False)  # Set unused subplots to invisible

plt.tight_layout()  # Adjust spacing
plt.show()

# %% [markdown]
# ##2. Correlation Matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlation matrices
correlation_matrix_X = X.corr()
correlation_matrix_X2 = X2.corr()

# Create subplots for side-by-side display
fig, axes = plt.subplots(1, 2, figsize=(20, 8))  # 1 row, 2 columns

# Plot Model A correlation matrix
sns.heatmap(correlation_matrix_X, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[0])
axes[0].set_title('Model A Features Correlation Matrix')

# Plot Model B correlation matrix
sns.heatmap(correlation_matrix_X2, annot=True, cmap='coolwarm', fmt=".2f", ax=axes[1])
axes[1].set_title('Model B Features Correlation Matrix')

plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %% [markdown]
# ##3. RFE (Recursive Feature Elimiation) To Visualize Feature Importance

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd  # Import pandas for DataFrame handling
from sklearn.linear_model import LinearRegression

# Assuming X and X2 are your DataFrames
# Add S_3pt_pct to X
X['S_3pt_pct'] = X2['S_3pt_pct']

# Create and fit the Linear Regression model
model = LinearRegression()
model.fit(X, y)

# Get feature names and coefficients
feature_names = X.columns
coefficients = model.coef_

# Sort features by coefficient magnitude (importance)
sorted_indices = np.argsort(np.abs(coefficients))[::-1]
sorted_feature_names = feature_names[sorted_indices]
sorted_coefficients = coefficients[sorted_indices]

# Create horizontal bar graph with highlighting and labels
plt.figure(figsize=(10, 6))
bars = plt.barh(sorted_feature_names, sorted_coefficients)  # Get bar objects
plt.xlabel("Coefficient Value (Importance)")
plt.ylabel("Features")
plt.title("Feature Importance from Linear Regression")

# Highlight bars and add labels
for bar, feature_name in zip(bars, sorted_feature_names):
    if feature_name in ['S_3pt_m', 'S_3pt_pct']:
        bar.set_facecolor('gold')  # Use 'gold' for a darker yellow

        # Add labels for Model A and Model B
        if feature_name == 'S_3pt_m':
            plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2,
                     'Model A', ha='left', va='center')
        elif feature_name == 'S_3pt_pct':
            plt.text(bar.get_width(), bar.get_y() + bar.get_height()/2,
                     'Model B', ha='left', va='center')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-140-4fdf00f79cd6>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['S_3pt_pct'] = X2['S_3pt_pct']

# %% [markdown]
# ##4. Scale the Data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# Fit the scaler to X and transform X
X_scaled = scaler.fit_transform(X)

# Fit the scaler to X2 and transform X2
X2_scaled = scaler.fit_transform(X2)

# %% [markdown]
# ##5. Train and Test Model

# %%
import statsmodels.api as sm

# --- Model A (using X) ---
# Add a constant to X (intercept term)
X = sm.add_constant(X)
# Fit the model and name it Model A
model_A = sm.OLS(y, X).fit()
# Print model summary
print("Model A:")
print(model_A.summary())  #

# --- Model B (using X2) ---
# Add a constant to X2 (intercept term)
X2 = sm.add_constant(X2)
# Fit the model and name it Model B
model_B = sm.OLS(y, X2).fit()
# Print model summary
print("\nModel B:")
print(model_B.summary())
# Out:
# Model A:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Win   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     2.307
# Date:                Fri, 25 Apr 2025   Prob (F-statistic):             0.0615
# Time:                        20:07:18   Log-Likelihood:                -12.169
# No. Observations:                  31   AIC:                             40.34
# Df Residuals:                      23   BIC:                             51.81
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.9512      0.737     -1.291      0.210      -2.476       0.573
# S_fg_pct       0.0409      0.016      2.629      0.015       0.009       0.073
# BC_to         -0.0436      0.017     -2.585      0.017      -0.079      -0.009
# S_3pt_m       -0.0264      0.041     -0.648      0.524      -0.111       0.058
# BC_stl         0.0064      0.015      0.418      0.680      -0.025       0.038
# R_reb          0.0232      0.010      2.306      0.030       0.002       0.044
# S_ft_pct      -0.0028      0.006     -0.496      0.625      -0.015       0.009
# S_3pt_pct     -0.0051      0.013     -0.387      0.702      -0.032       0.022
# ==============================================================================
# Omnibus:                        0.522   Durbin-Watson:                   0.737
# Prob(Omnibus):                  0.770   Jarque-Bera (JB):                0.559
# Skew:                          -0.274   Prob(JB):                        0.756
# Kurtosis:                       2.636   Cond. No.                         965.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Model B:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Win   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.252
# Method:                 Least Squares   F-statistic:                     2.687
# Date:                Fri, 25 Apr 2025   Prob (F-statistic):             0.0387
# Time:                        20:07:18   Log-Likelihood:                -12.449
# No. Observations:                  31   AIC:                             38.90
# Df Residuals:                      24   BIC:                             48.94
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0720      0.704     -1.522      0.141      -2.525       0.381
# S_fg_pct       0.0435      0.015      2.930      0.007       0.013       0.074
# BC_to         -0.0393      0.015     -2.569      0.017      -0.071      -0.008
# S_3pt_pct     -0.0102      0.010     -0.981      0.337      -0.032       0.011
# BC_stl         0.0035      0.014      0.245      0.809      -0.026       0.033
# R_reb          0.0213      0.010      2.240      0.035       0.002       0.041
# S_ft_pct      -0.0022      0.006     -0.400      0.693      -0.014       0.009
# ==============================================================================
# Omnibus:                        0.176   Durbin-Watson:                   0.772
# Prob(Omnibus):                  0.916   Jarque-Bera (JB):                0.355
# Skew:                          -0.134   Prob(JB):                        0.837
# Kurtosis:                       2.549   Cond. No.                         931.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ##6. Confusion Matrix

# %%
# prompt: help me run a confusion matrix on Model A using X as features and y as target, and on Model B using X2 as features and y as target, and display the confusion matrices side by side labeled Model A and Model B

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Assuming you have already trained your models (Model A and Model B) and have predictions:
# y_pred_A: Predictions from Model A
# y_pred_B: Predictions from Model B
# y_test: True labels

# Example predictions (replace with your actual predictions)
y_pred_A = model_A.predict(X) > 0.5 # Example using model_A, adjust threshold if needed.
y_pred_B = model_B.predict(X2) > 0.5 # Example using model_B, adjust threshold if needed.

# Calculate confusion matrices
cm_A = confusion_matrix(y, y_pred_A)
cm_B = confusion_matrix(y, y_pred_B)

# Plot confusion matrices side by side
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Model A Confusion Matrix
sns.heatmap(cm_A, annot=True, fmt="d", cmap="Blues", ax=axes[0],
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            cbar=False)
axes[0].set_title("Model A Confusion Matrix (Features: X)")  # Set title for Model A

# Model B Confusion Matrix
sns.heatmap(cm_B, annot=True, fmt="d", cmap="Blues", ax=axes[1],
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'],
            cbar=False)
axes[1].set_title("Model B Confusion Matrix (Features: X2)")  # Set title for Model B


plt.tight_layout()
plt.show()

# %% [markdown]
# ##7. Classification **Report**

# %%
from sklearn.metrics import classification_report

# Print classification reports side-by-side
print("## Model A Classification Report\n")
print(classification_report(y, y_pred_A))

print("\n## Model B Classification Report\n")  # Added newline for separation
print(classification_report(y, y_pred_B))
# Out:
# ## Model A Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.70      0.74        10
#            1       0.86      0.90      0.88        21
#
#     accuracy                           0.84        31
#    macro avg       0.82      0.80      0.81        31
# weighted avg       0.84      0.84      0.84        31
#
#
# ## Model B Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        10
#            1       0.86      0.86      0.86        21
#
#     accuracy                           0.81        31
#    macro avg       0.78      0.78      0.78        31
# weighted avg       0.81      0.81      0.81        31

# %% [markdown]
# #Summary
#
# ##Model A Outperformed Model B

# %% [markdown]
# ### Why?
#
# *   From our EDA, we observed multicollinearity between three-point percentage and field goal percentage — which makes sense, as all three-pointers are also field goals.
#
# *   Among all features, three-point percentage had the most skewed, non-normal distribution, even more than three-pointers made, which was less correlated with field goal percentage.
#
# *   Model A (using three-pointers made) outperformed Model B (which used three-point percentage instead) in both precision and accuracy.
#
# *   This is confirmed in the Classification Report: Model A achieved higher F1-scores (0.74 vs. 0.70 for class 0, and 0.88 vs. 0.86 for class 1), along with a higher overall accuracy (84% vs. 81%). The F1 score tells us how well a model balances precision (how often "yes" predictions are correct) and recall (how often it catches the real "yes" cases), so the stronger F1 scores in Model A show it was overall more reliable across both classes.
#
#
#
# *   👉 **View the interactive model in action:** https://shiny-duckanoo-d41e7c.netlify.app/
